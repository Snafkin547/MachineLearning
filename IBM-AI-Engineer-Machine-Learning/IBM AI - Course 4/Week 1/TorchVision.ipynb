# %%
import torch
import matplotlib.pylab as plt
import numpy as np
torch.manual_seed(0)

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + str(data_sample[1].item()))

# %%
# !conda install -y torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dsets
# Out:
# /bin/bash: conda: command not found

# %%
dataset = dsets.MNIST(
    root = './data',
    train = False,
    download = True,
    transform = transforms.ToTensor()
)

# %%
print("Type of the first element: ", type(dataset[0]))
print("The length of the tuple: ", len(dataset[0]))
print("The shape of the first element in the tuple: ", dataset[0][0].shape)
print("The type of the first element in the tuple", type(dataset[0][0]))
print("The second element in the tuple: ", dataset[0][1])
print("The type of the second element in the tuple: ", type(dataset[0][1]))
print("As the result, the structure of the first element in the dataset is (tensor([1, 28, 28]), tensor(7)).")
# Out:
# Type of the first element:  <class 'tuple'>
# The length of the tuple:  2
# The shape of the first element in the tuple:  torch.Size([1, 28, 28])
# The type of the first element in the tuple <class 'torch.Tensor'>
# The second element in the tuple:  7
# The type of the second element in the tuple:  <class 'int'>
# As the result, the structure of the first element in the dataset is (tensor([1, 28, 28]), tensor(7)).

# %%
show_data(dataset[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-741d3305a380> in <module>()
# ----> 1 show_data(dataset[0])
#
# <ipython-input-31-459811a2b60a> in show_data(data_sample, shape)
#       1 def show_data(data_sample, shape = (28, 28)):
# ----> 2     plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
#       3     plt.title('y = ' + str(data_sample[1].item()))
#
# ValueError: cannot reshape array of size 400 into shape (28,28)

# %%
croptensor_data_transform = transforms.Compose([transforms.CenterCrop(20), transforms.ToTensor()])
dataset = dsets.MNIST(root = './data', train = False, download = True, transform = croptensor_data_transform)
print("The shape of the first element in the first tuple: ", dataset[0][0].shape)
# Out:
# The shape of the first element in the first tuple:  torch.Size([1, 20, 20])

# %%
show_data(dataset[0], shape = (20,20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5f68eb8bcf5c> in <module>()
# ----> 1 show_data(dataset[0], shape = (20,20))
#
# <ipython-input-31-459811a2b60a> in show_data(data_sample, shape)
#       1 def show_data(data_sample, shape = (28, 28)):
#       2     plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
# ----> 3     plt.title('y = ' + str(data_sample[1].item()))
#
# AttributeError: 'int' object has no attribute 'item'

# %%
show_data(dataset[1], shape = (20,20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-eb1413918fa8> in <module>()
# ----> 1 show_data(dataset[1], shape = (20,20))
#
# <ipython-input-31-459811a2b60a> in show_data(data_sample, shape)
#       1 def show_data(data_sample, shape = (28, 28)):
#       2     plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
# ----> 3     plt.title('y = ' + str(data_sample[1].item()))
#
# AttributeError: 'int' object has no attribute 'item'

# %%
fliptensor_data_transform = transforms.Compose([transforms.RandomHorizontalFlip(p = 1), transforms.ToTensor()])
dataset = dsets.MNIST(root = './data', train = False, download = True, transform = fliptensor_data_transform)
show_data(dataset[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e244a1e3f683> in <module>()
#       1 fliptensor_data_transform = transforms.Compose([transforms.RandomHorizontalFlip(p = 1), transforms.ToTensor()])
#       2 dataset = dsets.MNIST(root = './data', train = False, download = True, transform = fliptensor_data_transform)
# ----> 3 show_data(dataset[1])
#
# <ipython-input-31-459811a2b60a> in show_data(data_sample, shape)
#       1 def show_data(data_sample, shape = (28, 28)):
#       2     plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
# ----> 3     plt.title('y = ' + str(data_sample[1].item()))
#
# AttributeError: 'int' object has no attribute 'item'

# %%
fliptensor_data_transform = transforms.Compose([transforms.RandomVerticalFlip(p = 1), transforms.ToTensor()])
dataset = dsets.MNIST(root = './data', train = False, download = True, transform = fliptensor_data_transform)
show_data(dataset[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-25c9ecfe8e27> in <module>()
#       1 fliptensor_data_transform = transforms.Compose([transforms.RandomVerticalFlip(p = 1), transforms.ToTensor()])
#       2 dataset = dsets.MNIST(root = './data', train = False, download = True, transform = fliptensor_data_transform)
# ----> 3 show_data(dataset[1])
#
# <ipython-input-31-459811a2b60a> in show_data(data_sample, shape)
#       1 def show_data(data_sample, shape = (28, 28)):
#       2     plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
# ----> 3     plt.title('y = ' + str(data_sample[1].item()))
#
# AttributeError: 'int' object has no attribute 'item'
