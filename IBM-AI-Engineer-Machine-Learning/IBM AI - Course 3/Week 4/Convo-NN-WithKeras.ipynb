# %%
import keras
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Dense
from keras.utils import to_categorical

# %%
from tensorflow.python.keras.layers.convolutional import Conv2D
from tensorflow.python.keras.layers.convolutional import MaxPooling2D
from tensorflow.python.keras.layers import Flatten

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %%
X_train =  X_train / 255
X_test = X_test / 255

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1]
num_classes
# Out:
# 10

# %%
def convolutional_model():
  model = Sequential()
  model.add(Conv2D(16,(5,5), strides=(1,1), activation='relu', input_shape=(28,28,1)))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = convolutional_model()

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 [==============================] - 16s 53ms/step - loss: 0.2927 - accuracy: 0.9168 - val_loss: 0.1310 - val_accuracy: 0.9642
# Epoch 2/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0944 - accuracy: 0.9723 - val_loss: 0.0698 - val_accuracy: 0.9790
# Epoch 3/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0652 - accuracy: 0.9808 - val_loss: 0.0515 - val_accuracy: 0.9842
# Epoch 4/10
# 300/300 [==============================] - 16s 52ms/step - loss: 0.0495 - accuracy: 0.9854 - val_loss: 0.0496 - val_accuracy: 0.9846
# Epoch 5/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0402 - accuracy: 0.9881 - val_loss: 0.0441 - val_accuracy: 0.9862
# Epoch 6/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.0404 - val_accuracy: 0.9860
# Epoch 7/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0275 - accuracy: 0.9919 - val_loss: 0.0372 - val_accuracy: 0.9875
# Epoch 8/10
# 300/300 [==============================] - 15s 50ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0399 - val_accuracy: 0.9870
# Epoch 9/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0361 - val_accuracy: 0.9880
# Epoch 10/10
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0429 - val_accuracy: 0.9854
# Accuracy: 0.9854000210762024
#  Error: 1.4599978923797607

# %%
def convolutional_model():

  model = Sequential()
  model.add(Conv2D(16, (5,5), activation='relu', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

  model.add(Conv2D(8,(2,2), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = convolutional_model()

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 16s - loss: 0.4507 - accuracy: 0.8715 - val_loss: 0.1298 - val_accuracy: 0.9614
# Epoch 2/10
# 300/300 - 15s - loss: 0.1160 - accuracy: 0.9651 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 3/10
# 300/300 - 16s - loss: 0.0817 - accuracy: 0.9755 - val_loss: 0.0605 - val_accuracy: 0.9814
# Epoch 4/10
# 300/300 - 16s - loss: 0.0655 - accuracy: 0.9800 - val_loss: 0.0554 - val_accuracy: 0.9827
# Epoch 5/10
# 300/300 - 16s - loss: 0.0555 - accuracy: 0.9834 - val_loss: 0.0475 - val_accuracy: 0.9857
# Epoch 6/10
# 300/300 - 16s - loss: 0.0484 - accuracy: 0.9854 - val_loss: 0.0454 - val_accuracy: 0.9850
# Epoch 7/10
# 300/300 - 16s - loss: 0.0423 - accuracy: 0.9871 - val_loss: 0.0363 - val_accuracy: 0.9872
# Epoch 8/10
# 300/300 - 15s - loss: 0.0389 - accuracy: 0.9884 - val_loss: 0.0376 - val_accuracy: 0.9871
# Epoch 9/10
# 300/300 - 16s - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0361 - val_accuracy: 0.9871
# Epoch 10/10
# 300/300 - 15s - loss: 0.0325 - accuracy: 0.9902 - val_loss: 0.0359 - val_accuracy: 0.9880
# Accuracy: 0.9879999756813049
#  Error: 1.2000024318695068
