# %%
import time
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
sess = tf.Session()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# !mkdir data
# !wget -q -O data/ptb.zip https://ibm.box.com/shared/static/z2yvmhbskc45xd2a9a4kkn6hg4g4kj5r.zip
# !unzip -o data/ptb.zip -d data
# !cp data/ptb/reader.py .

import reader
# Out:
# Archive:  data/ptb.zip
#    creating: data/ptb/
#   inflating: data/ptb/reader.py
#    creating: data/__MACOSX/
#    creating: data/__MACOSX/ptb/
#   inflating: data/__MACOSX/ptb/._reader.py
#   inflating: data/__MACOSX/._ptb

# %%
# !wget http://www.fit.vutbr.cz/~imikolov/rnnlm/simple-examples.tgz 
# !tar xzf simple-examples.tgz -C data/
# Out:
# --2020-04-15 11:03:08--  http://www.fit.vutbr.cz/~imikolov/rnnlm/simple-examples.tgz
# Resolving www.fit.vutbr.cz (www.fit.vutbr.cz)... 147.229.9.23, 2001:67c:1220:809::93e5:917
# Connecting to www.fit.vutbr.cz (www.fit.vutbr.cz)|147.229.9.23|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34869662 (33M) [application/x-gtar]
# Saving to: ‘simple-examples.tgz’
#
# simple-examples.tgz 100%[===================>]  33.25M  2.98MB/s    in 13s
#
# 2020-04-15 11:03:22 (2.60 MB/s) - ‘simple-examples.tgz’ saved [34869662/34869662]

# %%
init_scale = 0.1
learning_rate = 1.0
max_grad_norm = 5
num_layers = 2
num_steps = 20
hidden_size_l1 = 256
hidden_size_l2 = 128

max_epoch_decay_lr=4
max_epoch=15
keep_prob=1
decay=0.5
batch_size=60
vocab_size=10000
embeding_vector_size=200
is_training=1
data_dir="data/simple-examples/data/"

# %%
session=tf.InteractiveSession()

# %%
from tensorflow.compat.v1 import reader
raw_data = reader.ptb_raw_data(data_dir)
train_data, valid_data, test_data, vocab, word_to_id = raw_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-c512116937e3> in <module>()
# ----> 1 from tensorflow.compat.v1 import reader
#       2 raw_data = reader.ptb_raw_data(data_dir)
#       3 train_data, valid_data, test_data, vocab, word_to_id = raw_data
#
# ImportError: cannot import name 'reader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
train_size = int(0.7 * raw_data)
test_size = int(0.3 * raw_data)
train_data = full_dataset.take(train_size)
valid_data = full_dataset.skip(train_size)
test_data = full_dataset.take(test_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-15e791225606> in <module>()
# ----> 1 train_size = int(0.7 * raw_data)
#       2 test_size = int(0.3 * raw_data)
#       3 train_data = full_dataset.take(train_size)
#       4 valid_data = full_dataset.skip(train_size)
#       5 test_data = full_dataset.take(test_size)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'TextLineDatasetV1'

# %%
len(train_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-388b7f608497> in <module>()
# ----> 1 len(train_data)
#
# NameError: name 'train_data' is not defined

# %%
def id_to_word(id_list):
    line = []
    for w in id_list:
        for word, wid in word_to_id.item():
            if wid == w:
                 line.append(word)
    return line
print(id_to_word(raw_data[0:100]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-f92f23942462> in <module>()
#       6                  line.append(word)
#       7     return line
# ----> 8 print(id_to_word(raw_data[0:100]))
#
# TypeError: 'TextLineDatasetV1' object is not subscriptable

# %%
itera=reader_iterator(train_data, batch_size, num_steps)
first_touple = itera.__next__()
x = first_touple[0]
y = first_touple[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c9f74a80c8c2> in <module>()
# ----> 1 itera=reader_iterator(train_data, batch_size, num_steps)
#       2 first_touple = itera.__next__()
#       3 x = first_touple[0]
#       4 y = first_touple[1]
#
# NameError: name 'reader_iterator' is not defined

# %%
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9f2b259887ef> in <module>()
# ----> 1 x.shape
#
# NameError: name 'x' is not defined

# %%
x[0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-27249311b506> in <module>()
# ----> 1 x[0:3]
#
# NameError: name 'x' is not defined

# %%
_input_data = tf.placeholder(tf.int32, [batch_size, num_steps])
_targets = tf.placeholder(tf.int32, [batch_size, num_steps])

# %%
feed_dict = {_input_data:x, _targets:y}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b5412aa398c5> in <module>()
# ----> 1 feed_dict = {_input_data:x, _targets:y}
#
# NameError: name 'x' is not defined

# %%
session.run(_input_data, feed_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-779450d560e0> in <module>()
# ----> 1 session.run(_input_data, feed_dict)
#
# NameError: name 'feed_dict' is not defined

# %%
lstm_cell_l1 = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(hidden_size_l1, forget_bias=0.0)
lstm_cell_l2 = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(hidden_size_l2, forget_bias=0.0)
stacked_lstm = tf.compat.v1.nn.rnn_cell.MultiRNNCell([lstm_cell_1, lstm_cell_l2])
# Out:
# WARNING:tensorflow:From <ipython-input-46-3b4a766954ad>:1: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3b4a766954ad> in <module>()
#       1 lstm_cell_l1 = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(hidden_size_l1, forget_bias=0.0)
#       2 lstm_cell_l2 = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(hidden_size_l2, forget_bias=0.0)
# ----> 3 stacked_lstm = tf.compat.v1.nn.rnn_cell.MultiRNNCell([lstm_cell_1, lstm_cell_l2])
#
# NameError: name 'lstm_cell_1' is not defined

# %%
_initial_state = stacked_lstm.zero_state(batch_size, tf.float32)
_initial_state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a4741a858152> in <module>()
# ----> 1 _initial_state = stacked_lstm.zero_state(batch_size, tf.float32)
#       2 _initial_state
#
# NameError: name 'stacked_lstm' is not defined

# %%
session_vocab = tf.get_variable("embedding_vocab", [vocab_size, embeding_vector_size])

# %%
session.run(tf.global_variables_initializer())
session.run(embedding_vocab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-9014bc88c00c> in <module>()
#       1 session.run(tf.global_variables_initializer())
# ----> 2 session.run(embedding_vocab)
#
# NameError: name 'embedding_vocab' is not defined

# %%
session.run(inputs[0], feed_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-4d64d9ec7a64> in <module>()
# ----> 1 session.run(inputs[0], feed_dict)
#
# NameError: name 'inputs' is not defined

# %%
outputs, new_state = tf.nn.dynamic_rnn(stacked_lstm, inputs, initial_state=_initial_state)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-eb26e6ef7b2f> in <module>()
# ----> 1 outputs, new_state = tf.nn.dynamic_rnn(stacked_lstm, inputs, initial_state=_initial_state)
#
# NameError: name 'stacked_lstm' is not defined

# %%
outputs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-0dde94a30ad7> in <module>()
# ----> 1 outputs
#
# NameError: name 'outputs' is not defined

# %%
session.run(tf.global_variables_initializer())
session.run(outputs[0], feed_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-76f14cfb68e2> in <module>()
#       1 session.run(tf.global_variables_initializer())
# ----> 2 session.run(outputs[0], feed_dict)
#
# NameError: name 'outputs' is not defined

# %%
output=tf.reshape(outputs, [-1, hidden_size_l2])
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-b193a34bfb5e> in <module>()
# ----> 1 output=tf.reshape(outputs, [-1, hidden_size_l2])
#       2 output
#
# NameError: name 'outputs' is not defined

# %%
softmax_w=tf.get_variable("softmax_w", [hidden_size_l2, vocab_size])
softmax_b=tf.get_variable("softmax_b", [vocab_size])
logits=tf.mutual(output, softmax_w)+softmax_b
prob = tf.nn.softmax(logits)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-01d9fc95e67c> in <module>()
#       1 softmax_w=tf.get_variable("softmax_w", [hidden_size_l2, vocab_size])
#       2 softmax_b=tf.get_variable("softmax_b", [vocab_size])
# ----> 3 logits=tf.mutual(output, softmax_w)+softmax_b
#       4 prob = tf.nn.softmax(logits)
#
# AttributeError: module 'tensorflow.compat.v1' has no attribute 'mutual'

# %%
session.run(tf.global_variables_initializer())
output_words_prob = session.run(prob, feed_dict)
print("shape of the output: ", output_words_prob.shape)
print("The probability of observing words in t=0 to t=20", output_words_prob[0:20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-576a3c541c56> in <module>()
#       1 session.run(tf.global_variables_initializer())
# ----> 2 output_words_prob = session.run(prob, feed_dict)
#       3 print("shape of the output: ", output_words_prob.shape)
#       4 print("The probability of observing words in t=0 to t=20", output_words_prob[0:20])
#
# NameError: name 'prob' is not defined

# %%
np.argmax(output_words_prob[0:20], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-c790751cc335> in <module>()
# ----> 1 np.argmax(output_words_prob[0:20], axis=1)
#
# NameError: name 'output_words_prob' is not defined

# %%
y[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-5bfdbcf39e94> in <module>()
# ----> 1 y[0]
#
# NameError: name 'y' is not defined

# %%
targ = session.run(_targets, feed_dict)
targ[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5c924904e0d8> in <module>()
# ----> 1 targ = session.run(_targets, feed_dict)
#       2 targ[0]
#
# NameError: name 'feed_dict' is not defined

# %%
loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example([logits], [tf.reshape(_targets, [-1])],[tf.ones([batch_size * num_steps])])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-413e998cc769> in <module>()
# ----> 1 loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example([logits], [tf.reshape(_targets, [-1])],[tf.ones([batch_size * num_steps])])
#
# AttributeError: module 'tensorflow.compat.v1' has no attribute 'contrib'

# %%
session.run(loss, feed_dict)[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-8206ccb23d95> in <module>()
# ----> 1 session.run(loss, feed_dict)[:10]
#
# NameError: name 'loss' is not defined

# %%
cost = tf.reduce_sum(loss) / batch_size
session.run(tf.global_variables_initializer())
session.run(cost, feed_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-7e0d1911118e> in <module>()
# ----> 1 cost = tf.reduce_sum(loss) / batch_size
#       2 session.run(tf.global_variables_initializer())
#       3 session.run(cost, feed_dict)
#
# NameError: name 'loss' is not defined
